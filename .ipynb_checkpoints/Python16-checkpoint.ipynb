# %%
pip install kagglehub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("faviovaz/marketing-ab-testing")

# %%
path
# Out:
# 'C:\\Users\\D\\.cache\\kagglehub\\datasets\\faviovaz\\marketing-ab-testing\\versions\\1'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm

# %%
data = pd.read_csv(path + '\\marketing_AB.csv', index_col = 0)

# %%
data
# Out:
#         user id test group  converted  total ads most ads day  most ads hour
# 0       1069124         ad      False        130       Monday             20
# 1       1119715         ad      False         93      Tuesday             22
# 2       1144181         ad      False         21      Tuesday             18
# 3       1435133         ad      False        355      Tuesday             10
# 4       1015700         ad      False        276       Friday             14
# ...         ...        ...        ...        ...          ...            ...
# 588096  1278437         ad      False          1      Tuesday             23
# 588097  1327975         ad      False          1      Tuesday             23
# 588098  1038442         ad      False          3      Tuesday             23
# 588099  1496395         ad      False          1      Tuesday             23
# 588100  1237779         ad      False          1      Tuesday             23
#
# [588101 rows x 6 columns]

# %%
data['test group'].value_counts()
# Out:
# test group
# ad     564577
# psa     23524
# Name: count, dtype: int64

# %%
data.groupby('test group')['converted'].mean()
# Out:
# test group
# ad     0.025547
# psa    0.017854
# Name: converted, dtype: float64

# %% [markdown]
# ### Белый шум

# %%
sigma2 = 2
n = 1000
epsilon = np.random.normal(loc = 0, scale = sigma2, size = n)
time = pd.date_range(end = '2024-10-18', periods = n, freq = 'D')
data = pd.DataFrame({'series': epsilon}, index = time)

# %%
plt.figure(figsize = (15,4))
sns.lineplot(data)
plt.show()

# %% [markdown]
# Автокорреляция - это корреляция временного ряда и его лагов
#
# Лаги порядка h - это наблюдения временного ряда h периодов назад

# %%
stats.pearsonr(data['series'], data['lag4'])
# Out:
# PearsonRResult(statistic=np.float64(-0.032145526947652395), pvalue=np.float64(0.3108291835528353))

# %%
data['lag1'] = data['series'].shift()
data['lag2'] = data['series'].shift(2)
data['lag3'] = data['series'].shift(3)
data['lag4'] = data['series'].shift(4)
data = data.dropna()
print('Автокорреляция 1 порядка', data['series'].corr(data['lag1']))
print('Автокорреляция 2 порядка', data['series'].corr(data['lag2']))
print('Автокорреляция 3 порядка', data['series'].corr(data['lag3']))
print('Автокорреляция 4 порядка', data['series'].corr(data['lag4']))
# Out:
# Автокорреляция 1 порядка 0.011484116734070508
# Автокорреляция 2 порядка -0.00930017360180139
# Автокорреляция 3 порядка 0.006052633811702979
# Автокорреляция 4 порядка -0.0321455269476524

# %% [markdown]
# Существует автокорреляционная функция (ACF), которая показывает значения автокорреляции порядка h в зависимости от h

# %%
sm.graphics.tsa.plot_acf(data['series'], lags=20)
plt.show()

# %% [markdown]
# Если точка (значение автокорреляции) выпадает за границы области (области критических значений), то гипотеза о нулевой автокоррелиции может быть отвергнута => на этом порядке присутствует автокорреляция

# %% [markdown]
# ### Авторегрессия первого порядка (AR(1))

# %%
def simulate_ar_process(delta, phi, sigma2, n = 1000):
    epsilon = np.random.normal(loc = 0, scale = sigma2, size = n)
    time = pd.date_range(end = '2024-10-18', periods = n, freq = 'D')
    series = [delta]
    for t in range(n-1):
        y = delta + phi*series[t] + epsilon[t + 1]
        series.append(y)

    data = pd.DataFrame({'series': series}, index = time)
    
    plt.figure(figsize = (15,4))
    sns.lineplot(data.iloc[20:])
    plt.show()
    
    data['lag1'] = data['series'].shift()
    data['lag2'] = data['series'].shift(2)
    data['lag3'] = data['series'].shift(3)
    data['lag4'] = data['series'].shift(4)
    data = data.dropna()
    print('Автокорреляция 1 порядка', data['series'].corr(data['lag1']))
    print('Автокорреляция 2 порядка', data['series'].corr(data['lag2']))
    print('Автокорреляция 3 порядка', data['series'].corr(data['lag3']))
    print('Автокорреляция 4 порядка', data['series'].corr(data['lag4']))
    
    sm.graphics.tsa.plot_acf(data['series'], lags=20)
    plt.show()

# %% [markdown]
# #### Коэффициент авторeгресии = 0.9

# %%
simulate_ar_process(delta = 5, phi = 0.9, sigma2 =2)
# Out:
# Автокорреляция 1 порядка 0.8962449574015583
# Автокорреляция 2 порядка 0.8029461031996955
# Автокорреляция 3 порядка 0.7174256562898116
# Автокорреляция 4 порядка 0.64748386620646

# %% [markdown]
# #### Коэффициент авторегрессии -0,7

# %%
simulate_ar_process(delta = 3, phi = -0.7, sigma2 = 1)
# Out:
# Автокорреляция 1 порядка -0.7116100689646937
# Автокорреляция 2 порядка 0.4884943594360344
# Автокорреляция 3 порядка -0.3329460524132705
# Автокорреляция 4 порядка 0.23673748865775093

# %% [markdown]
# #### Коэффициент авторегрессии 1,01

# %%
simulate_ar_process(delta = 3, phi = 1.01, sigma2 = 1)
# Out:
# Автокорреляция 1 порядка 0.9999999999996593
# Автокорреляция 2 порядка 0.9999999999993485
# Автокорреляция 3 порядка 0.9999999999990302
# Автокорреляция 4 порядка 0.9999999999987292

# %% [markdown]
# #### Коэффициент авторегрессии равен 1 (случайное блуждание - random walk)

# %%
simulate_ar_process(delta = 0, phi = 1, sigma2 = 2)
# Out:
# Автокорреляция 1 порядка 0.9920790985198662
# Автокорреляция 2 порядка 0.9844450645505738
# Автокорреляция 3 порядка 0.9772960739648028
# Автокорреляция 4 порядка 0.9696564270770115

# %% [markdown]
# ### Модели скользящего среднего

# %%
def simulate_ma_process(mu, theta, sigma2, n = 1000):
    epsilon = np.random.normal(loc = 0, scale = sigma2, size = n)
    time = pd.date_range(end = '2024-10-18', periods = n, freq = 'D')
    series = [epsilon[0]]
    for t in range(n-1):
        y = mu + theta*epsilon[t] + epsilon[t + 1]
        series.append(y)

    data = pd.DataFrame({'series': series}, index = time)
    
    plt.figure(figsize = (15,4))
    sns.lineplot(data.iloc[20:])
    plt.show()
    
    data['lag1'] = data['series'].shift()
    data['lag2'] = data['series'].shift(2)
    data['lag3'] = data['series'].shift(3)
    data['lag4'] = data['series'].shift(4)
    data = data.dropna()
    print('Автокорреляция 1 порядка', data['series'].corr(data['lag1']))
    print('Автокорреляция 2 порядка', data['series'].corr(data['lag2']))
    print('Автокорреляция 3 порядка', data['series'].corr(data['lag3']))
    print('Автокорреляция 4 порядка', data['series'].corr(data['lag4']))
    
    sm.graphics.tsa.plot_acf(data['series'], lags=20)
    plt.show()

# %% [markdown]
# #### Тета = 0.9

# %%
simulate_ma_process(mu = 0, theta = 0.9, sigma2 = 2, n = 1000)
# Out:
# Автокорреляция 1 порядка 0.4613065903756362
# Автокорреляция 2 порядка -0.034407775416480074
# Автокорреляция 3 порядка 0.021697122120132667
# Автокорреляция 4 порядка 0.04049795061386523

# %% [markdown]
# #### Тета = -0.5

# %%
simulate_ma_process(mu = 5, theta = -0.5, sigma2 = 2, n = 1000)
# Out:
# Автокорреляция 1 порядка -0.39215196888996684
# Автокорреляция 2 порядка -0.016170147712565013
# Автокорреляция 3 порядка 0.006507534219495545
# Автокорреляция 4 порядка 0.03457687925574656

# %% [markdown]
# #### Тета  = 1,1

# %%
simulate_ma_process(mu = 5, theta = 1.1, sigma2 = 2, n = 1000)
# Out:
# Автокорреляция 1 порядка 0.5025663594112587
# Автокорреляция 2 порядка -0.01920608022351991
# Автокорреляция 3 порядка -0.01717840106672946
# Автокорреляция 4 порядка 0.000538064873443316

# %% [markdown]
# 1) Если процесс стационарный, то наиболее простыми моделями для его описания являются AR или MA модели
#
# 2) Если график автокорреляции показывает продолжительное убывающее значение автокорреляции на множестве лагов, то, скорее всего, подходящей моделью будет является AR
#
# 3) Если график автокорреляции показывает значимую корреляция только одного лага, то, скорее всего, подходящей моделью будет являться MA

# %% [markdown]
# ### Стационарность и нестационарность

# %% [markdown]
# Стационарный временной ряд не меняет со временем своих основных характеристик: среднее значение и дисперсия
#
# Две ситуации нестационарности:
#
# 1) Наличие тренда (детерминированного либо стохастического)
#
# 2) Наличие разрывов

# %% [markdown]
# ### Детерминированный линейный тренд

# %%
def simulate_linear_trend_process(b0, b1, delta, phi, sigma2, n = 1000):
    epsilon = np.random.normal(loc = 0, scale = sigma2, size = n)
    time = pd.date_range(end = '2024-10-18', periods = n, freq = 'D')
    series = [delta]
    for t in range(n-1):
        trend = b0 + b1*t
        y = trend  +  delta + phi*series[t] + epsilon[t + 1] 
        series.append(y)

    data = pd.DataFrame({'series': series}, index = time)
    
    plt.figure(figsize = (15,4))
    sns.lineplot(data.iloc[20:])
    plt.show()
    
    data['lag1'] = data['series'].shift()
    data['lag2'] = data['series'].shift(2)
    data['lag3'] = data['series'].shift(3)
    data['lag4'] = data['series'].shift(4)
    data = data.dropna()
    print('Автокорреляция 1 порядка', data['series'].corr(data['lag1']))
    print('Автокорреляция 2 порядка', data['series'].corr(data['lag2']))
    print('Автокорреляция 3 порядка', data['series'].corr(data['lag3']))
    print('Автокорреляция 4 порядка', data['series'].corr(data['lag4']))
    
    sm.graphics.tsa.plot_acf(data['series'], lags=20)
    plt.show()

# %%
simulate_linear_trend_process(b0 = 1, b1 = 2, delta = 10, phi = 0.9 , sigma2 = 500, n = 1000)
# Out:
# Автокорреляция 1 порядка 0.9965578427946508
# Автокорреляция 2 порядка 0.9935151735361607
# Автокорреляция 3 порядка 0.9909313552724945
# Автокорреляция 4 порядка 0.9884317723440733

# %% [markdown]
# ### Детерминированный квадратичный тренд

# %%
def simulate_quadratic_trend_process(b0, b1, b2, delta, phi, sigma2, n = 1000):
    epsilon = np.random.normal(loc = 0, scale = sigma2, size = n)
    time = pd.date_range(end = '2024-10-18', periods = n, freq = 'D')
    series = [delta]
    for t in range(n-1):
        trend = b0 + b1*t + b2*(t**2)
        y = trend  +  delta + phi*series[t] + epsilon[t + 1] 
        series.append(y)

    data = pd.DataFrame({'series': series}, index = time)
    
    plt.figure(figsize = (15,4))
    sns.lineplot(data.iloc[20:])
    plt.show()
    
    data['lag1'] = data['series'].shift()
    data['lag2'] = data['series'].shift(2)
    data['lag3'] = data['series'].shift(3)
    data['lag4'] = data['series'].shift(4)
    data = data.dropna()
    print('Автокорреляция 1 порядка', data['series'].corr(data['lag1']))
    print('Автокорреляция 2 порядка', data['series'].corr(data['lag2']))
    print('Автокорреляция 3 порядка', data['series'].corr(data['lag3']))
    print('Автокорреляция 4 порядка', data['series'].corr(data['lag4']))
    
    sm.graphics.tsa.plot_acf(data['series'], lags=20)
    plt.show()

# %%
simulate_quadratic_trend_process(b0 = 1, b1 = 4, b2 = -0.002, delta = 10, phi = 0.9, sigma2 = 500, n = 1000)
# Out:
# Автокорреляция 1 порядка 0.9962390638209998
# Автокорреляция 2 порядка 0.9930200510874349
# Автокорреляция 3 порядка 0.9899076610020966
# Автокорреляция 4 порядка 0.987199610838336
