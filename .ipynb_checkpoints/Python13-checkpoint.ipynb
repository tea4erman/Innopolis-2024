# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data = pd.read_csv(r"C:\Courses\Innopolis\2024\ПИШ\Часть 2.2\Консультация\all_v2.csv")

# %%
data.head()
# Out:
#      price        date      time    geo_lat    geo_lon  region  building_type  \
# 0  6050000  2018-02-19  20:00:21  59.805808  30.376141    2661              1
# 1  8650000  2018-02-27  12:04:54  55.683807  37.297405      81              3
# 2  4000000  2018-02-28  15:44:00  56.295250  44.061637    2871              1
# 3  1850000  2018-03-01  11:24:52  44.996132  39.074783    2843              4
# 4  5450000  2018-03-01  17:42:43  55.918767  37.984642      81              3
#
#    level  levels  rooms  area  kitchen_area  object_type
# 0      8      10      3  82.6          10.8            1
# 1      5      24      2  69.1          12.0            1
# 2      5       9      3  66.0          10.0            1
# 3     12      16      2  38.0           5.0           11
# 4     13      14      2  60.0          10.0            1

# %%
data.shape
# Out:
# (5477006, 13)

# %%
df = data.sample(frac = 0.01, random_state = 42).reset_index(drop = True)
df
# Out:
#           price        date      time    geo_lat    geo_lon  region  \
# 0      13719304  2020-06-02  21:21:22  55.869536  37.458076       3
# 1       1601000  2019-06-30  06:06:07  55.030393  83.015545    9654
# 2       1200000  2019-08-21  02:37:16  55.030393  83.015545    9654
# 3       1650000  2018-12-19  22:04:21  45.141191  38.992274    2843
# 4       6100000  2020-11-18  18:26:54  43.651925  39.652122    2843
# ...         ...         ...       ...        ...        ...     ...
# 54765   2000000  2019-10-03  07:17:35  45.065667  39.004715    2843
# 54766   2483000  2020-02-26  16:13:33  53.195031  50.106952    3106
# 54767   5826240  2021-01-31  04:13:45  55.664012  37.855070      81
# 54768   3500000  2020-04-09  08:18:33  56.446714  53.751745    1010
# 54769   9048590  2018-12-30  14:13:05  55.874485  37.597773       3
#
#        building_type  level  levels  rooms   area  kitchen_area  object_type
# 0                  2      5      20      1  53.00          10.0           11
# 1                  1      5      10      3  59.02           8.5           11
# 2                  1      1      10     -1  33.58           5.0           11
# 3                  2      6       7      1  40.00          10.0            1
# 4                  2      6      13      2  47.60          10.0           11
# ...              ...    ...     ...    ...    ...           ...          ...
# 54765              4      7      16      1  40.00          11.0           11
# 54766              3      5       8      1  48.00          13.0           11
# 54767              1     15      25      1  35.70          17.0           11
# 54768              3      2       5      4  77.20          10.0            1
# 54769              1     22      24      2  52.70          12.3           11
#
# [54770 rows x 13 columns]

# %%
df['date'].max()
# Out:
# '2021-05-01'

# %%
sns.set(palette = 'deep')
sns.lineplot(data = df[df['date']>='2021-04-01'], x = 'date', y = 'area', hue = 'rooms', errorbar = ('ci', 99))
# Out:
# <Axes: xlabel='date', ylabel='area'>

# %% [markdown]
# #### Доверительный интервал для площади 1к и 2к квартир

# %%
df1k = df.loc[df['rooms']==1, 'area']
df2k = df.loc[df['rooms']==2, 'area']

alpha = 0.95

ci1k = stats.norm.interval(confidence = alpha, loc = df1k.mean(), scale = np.sqrt(df1k.var()/df1k.count()))
print(f'95% доверительный интервал для средней площади 1к квартиры от {ci1k[0].round(2)} до {ci1k[1].round(2)} кв м')

ci2k = stats.norm.interval(confidence = alpha, loc = df2k.mean(), scale = np.sqrt(df2k.var()/df2k.count()))
print(f'95% доверительный интервал для средней площади 2к квартиры от {ci2k[0].round(2)} до {ci2k[1].round(2)} кв м')
# Out:
# 95% доверительный интервал для средней площади 1к квартиры от 38.02 до 38.28 кв м
# 95% доверительный интервал для средней площади 2к квартиры от 55.05 до 55.5 кв м

# %%
fig = plt.figure()
sns.histplot(df1k[df1k<100], kde = True)
plt.vlines(x = ci1k[0], ymin = 0, ymax = 700, color = 'r')
plt.vlines(x = ci1k[1], ymin = 0, ymax = 700, color = 'r')
plt.show()

# %% [markdown]
# #### Корреляция

# %%
df['area'].corr(df['rooms'])
# Out:
# np.float64(0.6453949494405004)

# %%
df['area'].corr(df['kitchen_area'])
# Out:
# np.float64(0.5039221538170033)

# %% [markdown]
# #### Регрессия

# %%
sns.lmplot(data = df, x = 'rooms', y = 'area')

# %%
sns.lmplot(data = df[(df['rooms']<=3)&(df['rooms']>0)&(df['area']<100)], x = 'area', y = 'kitchen_area', hue = 'rooms')

# %% [markdown]
# #### Тесты на нормальность распределения

# %% [markdown]
# ##### Тест Шапиро-Уилка

# %%
stats.shapiro(df1k[df1k<100])
# Out:
# ShapiroResult(statistic=np.float64(0.9699926245679857), pvalue=np.float64(1.39834465587304e-24))

# %% [markdown]
# p-значение очень маленькое, т.е. нулевая гипотеза отвергается и распределение нельзя считать нормальным

# %% [markdown]
# ##### Тест Андерсона-Дарлинга

# %%
stats.anderson(df1k[df1k<100], dist='norm')
# Out:
# AndersonResult(statistic=np.float64(143.56757573443974), critical_values=array([0.576, 0.656, 0.787, 0.918, 1.092]), significance_level=array([15. , 10. ,  5. ,  2.5,  1. ]), fit_result=  params: FitParams(loc=np.float64(38.018475506960165), scale=np.float64(7.832020572930531))
#  success: True
#  message: '`anderson` successfully fit the distribution to the data.')

# %% [markdown]
# Для уровня значимости 0,05 критическое значение составляет 0,787, а наблюдаемое значение 143,57
#
# Наблюдаемая статистика гораздо выше критического значения => отвергаем нулевую гипотезу

# %% [markdown]
# ##### Тест Колмогорова-Смирнова

# %%
stats.kstest(df1k[df1k<100], stats.norm.cdf)
# Out:
# KstestResult(statistic=np.float64(0.9994586951367119), pvalue=np.float64(0.0), statistic_location=np.float64(3.7), statistic_sign=np.int8(-1))

# %% [markdown]
# р-значение является очень низким, т.е. нулевая гипотеза отвергается. Распределение площади 1к квартир не является нормальным

# %% [markdown]
# #### T-тесты

# %%
df1k_price = df.loc[(df['rooms']==1)&(df['area']<100)&(df['price']<5000000), 'price']
df2k_price = df.loc[(df['rooms']==2)&(df['area']<100)&(df['price']<5000000), 'price']

# %% [markdown]
# ##### Тест о математическом ожидании (одновыборочный t-тест)

# %%
df1k_price.mean()
# Out:
# np.float64(2314005.0722600482)

# %%
df2k_price.mean()
# Out:
# np.float64(2771999.4060099414)

# %% [markdown]
# Протестируем гипотезу о том, что математическое ожидание цены 1к квартиры составляет 2300000 рублей

# %%
stats.ttest_1samp(df1k_price, popmean = 2300000, alternative = 'two-sided')
# Out:
# TtestResult(statistic=np.float64(1.8453235562650858), pvalue=np.float64(0.06500670973543665), df=np.int64(18211))

# %% [markdown]
# p-значение более 5%, то есть нулевую гипотезу отвергнуть нельзя
#
# Средняя цена 1к квартиры может составлять 2 300 000 рублей

# %% [markdown]
# ##### Тест о равенстве мат ожиданий (двухвыборочный t-тест)

# %%
stats.ttest_ind(df1k_price, df2k_price, alternative = 'two-sided')
# Out:
# TtestResult(statistic=np.float64(-39.19941070211349), pvalue=np.float64(0.0), df=np.float64(31488.0))

# %% [markdown]
# p-значение оказалось ниже 5%, то есть нулевая гипотеза о том, что средние цены 1к и 2к квартир равны, отвергается
