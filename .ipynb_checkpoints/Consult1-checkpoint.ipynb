# %% [markdown]
# ### Exercise 1 (page 99)

# %%
a = input('Длина 1 стороны: \n')
b = input('Длина 2 стороны: \n')
c = input('Длина 3 стороны: \n')

try:
    a = float(a)
    b = float(b)
    c = float(c)
    if (a == b)&(b == c):
        print('Треугольник равносторонний')
    else:
        print('Треугольник не равносторонний')
        
except:
    print('Все длины должны быть в виде чисел!')
# Out:
# Длина 1 стороны:
# фывфыв
# Длина 2 стороны:
# 10
# Длина 3 стороны:
# 15
# Все длины должны быть в виде чисел!

# %% [markdown]
# ### Exercise 2  (page 99)

# %%
a = input('Длина 1 стороны: \n')
b = input('Длина 2 стороны: \n')
c = input('Длина 3 стороны: \n')

try:
    a = float(a)
    b = float(b)
    c = float(c)
    if a**2 == b**2 + c**2:
        print('Треугольник прямоугольный')
    elif b**2 == a**2 + c**2:
        print('Треугольник прямоугольный')
    elif c**2 == a**2 + b**2:
        print('Треугольник прямоугольный')
    else:
        print('Треугольник не прямоугольный')
        
except:
    print('Все длины должны быть в виде чисел!')
# Out:
# Длина 1 стороны:
# ываы
# Длина 2 стороны:
# 45
# Длина 3 стороны:
# 12
# Все длины должны быть в виде чисел!

# %%
a = input('Длина 1 стороны: \n')
b = input('Длина 2 стороны: \n')
c = input('Длина 3 стороны: \n')

try:
    a = float(a)
    b = float(b)
    c = float(c)
    if (a**2 == b**2 + c**2) or (b**2 == a**2 + c**2) or (c**2 == a**2 + b**2):
        print('Треугольник прямоугольный')
    else:
        print('Треугольник не прямоугольный')
        
except:
    print('Все длины должны быть в виде чисел!')
# Out:
# Длина 1 стороны:
# 5
# Длина 2 стороны:
# 4
# Длина 3 стороны:
# 3
# Треугольник прямоугольный

# %% [markdown]
# ### Exercise 6  (page 100)

# %%
n = input('Введите число итераций \n')
n = int(n)

result = 0

for i in range(n):
    if i%2 == 0:
        result = result + 1/(2*i+1)
    else:
        result = result - 1/(2*i+1)

print('Число пи составляет', result * 4)
# Out:
# Введите число итераций
# 50000
# Число пи составляет 3.1415726535897814

# %%
n = input('Введите число итераций \n')
n = int(n)

result = 0

for i in range(n):
    result = result + (1/(2*i+1)) * (-1)**i

print('Число пи составляет', result * 4)
# Out:
# Введите число итераций
# 50000
# Число пи составляет 3.1415726535897814

# %% [markdown]
# ### Exercise 9 (page 101)

# %%
s = 0
n = 0

while True:
    num = input('Введите число \n')
    if num == '':
        break
    else:
        s = s + float(num)
        n = n + 1
print('Сумма равна', s)
print('Средняя равна', s/n)
# Out:
# Введите число
# 10
# Введите число
# 12
# Введите число
# 15
# Введите число
#
# Сумма равна 37.0
# Средняя равна 12.333333333333334

# %%
import numpy as np

numbers = []

while True:
    num = input('Введите число \n')
    if num == '':
        break
    else:
        numbers.append(float(num))

arr = np.array(numbers)        
print('Сумма равна', arr.sum())
print('Средняя равна', arr.mean())
# Out:
# Введите число
# 10
# Введите число
# 15
# Введите число
# 17
# Введите число
#
# Сумма равна 42.0
# Средняя равна 14.0

# %% [markdown]
# ### Exercise 1 (page 165)

# %%
numbers = [15, 16, 17, 18, 20, 10, 10, 12]

n = len(numbers)

numbers.sort()

if n%2 == 0:
    a = int(n/2 - 1)
    b = int(n/2)
    median = (numbers[a] + numbers[b]) / 2
else:
    a = int((n - 1)/2 )
    median = numbers[a]
    
print(median)
# Out:
# 15.5

# %%
numbers = [15, 16, 20, 20, 20, 10, 10, 12]
numbers.sort()
x = np.array(numbers) 
counts = np.unique(x, return_counts = True)
n = counts[1].argmax()
mode = counts[0][n]
print('Мода равна', mode)
# Out:
# Мода равна 20

# %%
n = len(numbers)
i = 0
a = numbers.pop(0)
while i < n:
    b = numbers.pop(0)
    if
# Out:
# [10, 10, 12, 15, 16, 17, 18, 20]

# %% [markdown]
# ### Словари и годы

# %%
years = {
    1: 'год',
    2: 'года',
    3: 'года',
    4: 'года',
    5: 'лет',
    6: 'лет',
    7: 'лет',
    8: 'лет',
    9: 'лет',
    10: 'лет'
}

# %%
y = input("Введите число от 1 до 10 \n")
y = int(y)
print("Вы ввели", y, years[y])
# Out:
# Введите число от 1 до 10
# 6
# Вы ввели 6 лет

# %%
numbers = [15, 16, 20, 20, 20, 10, 10, 12]

# %%
# %%timeit

nums = {}
for num in set(numbers):
    nums[num] = numbers.count(num)
    max_count = max(nums.values())
list(nums.keys())[list(nums.values()).index(3)]
# Out:
# 4.45 µs ± 92.3 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
list(nums.values()).index(3)
# Out:
# 4

# %%
# %%timeit

cnt = 0
for num in numbers:
    if numbers.count(num) > cnt:
        cnt = numbers.count(num)
        mode = num
# Out:
# 1.84 µs ± 46.7 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
mode
# Out:
# 20
