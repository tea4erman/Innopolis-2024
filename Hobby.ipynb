# %%
import pandas as pd

# %% [markdown]
# ### 1. Сбор данных

# %%
data = pd.read_spss(r"C:\Courses\Innopolis\2024\ПИШ\Лекция 1\Hobby.sav")

# %%
data.head()
# Out:
#                  ID      SEX   AGE                             FO  \
# 0  07bb6363cc4ce853  Мужской  34.0  Центральный федеральный округ
# 1  07bb4e2e030ce26a  Женский  48.0  Центральный федеральный округ
# 2  07bb84edd28ced54  Мужской  27.0        Южный федеральный округ
# 3  07bb4eedfc8ce37b  Мужской  25.0  Центральный федеральный округ
# 4  07bb5e4b450cecbc  Мужской  29.0  Приволжский федеральный округ
#
#                                                  TIP  \
# 0  Город с численностью жителей миллион и более ч...
# 1     Город с численностью от 100 тысяч до 500 тысяч
# 2  Город с численностью жителей миллион и более ч...
# 3  Город с численностью жителей миллион и более ч...
# 4     Город с численностью от 500 тысяч до 950 тысяч
#
#                                                Hb1_1  \
# 0  Hb1. Сменим тему. Есть ли у Вас хОбби -- увлеч...
# 1  Hb1. Сменим тему. Есть ли у Вас хОбби -- увлеч...
# 2  Hb1. Сменим тему. Есть ли у Вас хОбби -- увлеч...
# ...

# %% [markdown]
# ### 2. Подготовка данных

# %%
sample = data[['SEX', 'AGE', 'Hb1_1d']]

# %%
sample.columns = ['Sex', 'Age', 'Hobby']
sample
# Out:
#           Sex   Age                           Hobby
# 0     Мужской  34.0  Спорт / спортзал / физкультура
# 1     Женский  48.0                       Вышивание
# 2     Мужской  27.0  Спорт / спортзал / физкультура
# 3     Мужской  25.0   Видеоигры / компьютерные игры
# 4     Мужской  29.0  Спорт / спортзал / физкультура
# ...       ...   ...                             ...
# 1606  Мужской  45.0            Затрудняюсь ответить
# 1607  Женский  49.0            Затрудняюсь ответить
# 1608  Женский  71.0            Затрудняюсь ответить
# 1609  Мужской  18.0            Затрудняюсь ответить
# 1610  Мужской  64.0            Затрудняюсь ответить
#
# [1611 rows x 3 columns]

# %% [markdown]
# ### 3. Визуализация

# %%
youngers = sample[sample['Age'] <= 30]

# %%
youngers['Sex'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (15,5))
youngers['Hobby'].value_counts().head(10).plot(kind = 'bar')
plt.show()
